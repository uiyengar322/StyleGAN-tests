# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms as T
from torch.utils.data import DataLoader
from torchvision.utils import save_image
import matplotlib.pyplot as plt
import numpy as np
from ignite.metrics import FID, InceptionScore
from ignite.engine import Engine
import PIL.Image as Image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(nn.ConvTranspose2d(latent_size, 512, 4, stride=1, padding=0, bias=False),
                                 nn.BatchNorm2d(512),
                                 nn.ReLU(True),
                                 nn.ConvTranspose2d(512, 256, 4, stride=2, padding=1, bias=False),
                                 nn.BatchNorm2d(256),
                                 nn.ReLU(True),
                                 nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1, bias=False),
                                 nn.BatchNorm2d(128),
                                 nn.ReLU(True),
                                 nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1, bias=False),
                                 nn.BatchNorm2d(64),
                                 nn.ReLU(True),
                                 nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1, bias=False),
                                 nn.BatchNorm2d(32),
                                 nn.ReLU(True),
                                 nn.ConvTranspose2d(32, 3, 3, stride=1, padding=1, bias=False),
                                 nn.Tanh())

    def forward(self, x):
        x = x.view(x.size(0), latent_size, 1, 1)
        return self.gen(x)

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(nn.Conv2d(3, 32, 3, stride=1, padding=1, bias=False),
                                  nn.LeakyReLU(0.2, inplace=True),
                                  nn.Conv2d(32, 64, 4, stride=2, padding=1, bias=False),
                                  nn.BatchNorm2d(64),
                                  nn.LeakyReLU(0.2, inplace=True),
                                  nn.Conv2d(64, 128, 4, stride=2, padding=1, bias=False),
                                  nn.BatchNorm2d(128),
                                  nn.LeakyReLU(0.2, inplace=True),
                                  nn.Conv2d(128, 256, 4, stride=2, padding=1, bias=False),
                                  nn.BatchNorm2d(256),
                                  nn.LeakyReLU(0.2, inplace=True),
                                  nn.Conv2d(256, 512, 4, stride=2, padding=1, bias=False),
                                  nn.BatchNorm2d(512),
                                  nn.LeakyReLU(0.2, inplace=True),
                                  nn.Conv2d(512, 1, 4, stride=1, padding=0, bias=False),
                                  nn.Sigmoid())

    def forward(self, x):
        return self.disc(x)

# %%
latent_size = 100
num_epochs = 150
batch_size = 32
learning_rate = 0.0005

transform=T.Compose([T.Resize((64,64)),
                     T.ToTensor(),
                     T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = datasets.ImageFolder('./city/train',transform=transform)
train_loader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2)

def check_input(img):
    img = img / 2 + 0.5
    plt.figure(figsize=(15,15))
    grid = torchvision.utils.make_grid(img, ncol=8)
    plt.imshow(grid.permute(1, 2, 0))
    plt.axis('off')
    plt.title('Grid of Real Images from the Training Set')
    plt.show()
img,lab=next(iter(train_loader))
check_input(img)

# %%
gen = Generator().to(device)
disc = Discriminator().to(device)

gen.apply(weights_init)
disc.apply(weights_init)

loss = nn.BCELoss()

optimizer_g = optim.Adam(gen.parameters(), lr=0.0005, betas=(0.5, 0.999))
optimizer_d = optim.Adam(disc.parameters(), lr=0.0005, betas=(0.5, 0.999))

finald=[]
finalg=[]

total_step = len(train_loader)
for epoch in range(num_epochs):
    for t, (real_images, y) in enumerate(train_loader):
        batch_size = real_images.size(0)
        real_images = real_images.to(device)

        disc.zero_grad()
        outputs = disc(real_images)
        real_loss = loss(outputs, torch.ones_like(outputs))
        z = torch.randn(batch_size, latent_size, 1, 1).to(device)
        fake_images = gen(z)
        outputs = disc(fake_images.detach())
        fake_loss = loss(outputs, torch.zeros_like(outputs))
        d_loss = real_loss + fake_loss
        d_loss.backward(retain_graph=True)
        optimizer_d.step()

        gen.zero_grad()
        outputs = disc(fake_images)
        g_loss = loss(outputs, torch.ones_like(outputs))
        g_loss.backward()
        optimizer_g.step()

        if (t + 1) % 67 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}'
                  .format(epoch+1, num_epochs, t + 1, total_step, d_loss.item(), g_loss.item()))

        finald.append(d_loss.item())
        finalg.append(g_loss.item())
# Out:
# Epoch [1/150], Step [67/67], d_loss: 0.9621, g_loss: 4.3990
# Epoch [2/150], Step [67/67], d_loss: 0.3878, g_loss: 5.6167
# Epoch [3/150], Step [67/67], d_loss: 0.4906, g_loss: 3.4810
# Epoch [4/150], Step [67/67], d_loss: 0.8433, g_loss: 2.0029
# Epoch [5/150], Step [67/67], d_loss: 0.7808, g_loss: 4.1000
# Epoch [6/150], Step [67/67], d_loss: 1.2884, g_loss: 2.7607
# Epoch [7/150], Step [67/67], d_loss: 1.3570, g_loss: 1.7576
# Epoch [8/150], Step [67/67], d_loss: 0.9095, g_loss: 2.4522
# Epoch [9/150], Step [67/67], d_loss: 0.8102, g_loss: 3.0419
# Epoch [10/150], Step [67/67], d_loss: 0.4974, g_loss: 4.1087
# Epoch [11/150], Step [67/67], d_loss: 0.6409, g_loss: 4.1185
# Epoch [12/150], Step [67/67], d_loss: 0.4615, g_loss: 3.7121
# Epoch [13/150], Step [67/67], d_loss: 0.9241, g_loss: 2.7552
# Epoch [14/150], Step [67/67], d_loss: 0.6272, g_loss: 2.9900
# Epoch [15/150], Step [67/67], d_loss: 1.1233, g_loss: 5.2215
# Epoch [16/150], Step [67/67], d_loss: 0.9156, g_loss: 4.2299
# Epoch [17/150], Step [67/67], d_loss: 0.7504, g_loss: 4.4668
# Epoch [18/150], Step [67/67], d_loss: 0.7424, g_loss: 5.6730
# Epoch [19/150], Step [67/67], d_loss: 0.2634, g_loss: 4.6227
# Epoch [20/150], Step [67/67], d_loss: 1.0181, g_loss: 1.5158
# Epoch [21/150], Step [67/67], d_loss: 0.6845, g_loss: 3.2935
# Epoch [22/150], Step [67/67], d_loss: 0.7620, g_loss: 5.4502
# Epoch [23/150], Step [67/67], d_loss: 0.7186, g_loss: 3.7718
# Epoch [24/150], Step [67/67], d_loss: 1.5528, g_loss: 1.4196
# Epoch [25/150], Step [67/67], d_loss: 1.0097, g_loss: 7.7904
# Epoch [26/150], Step [67/67], d_loss: 0.6434, g_loss: 4.9924
# Epoch [27/150], Step [67/67], d_loss: 0.3786, g_loss: 4.8665
# Epoch [28/150], Step [67/67], d_loss: 0.3627, g_loss: 4.8843
# Epoch [29/150], Step [67/67], d_loss: 1.0219, g_loss: 3.9651
# Epoch [30/150], Step [67/67], d_loss: 0.6560, g_loss: 7.2604
# Epoch [31/150], Step [67/67], d_loss: 0.3830, g_loss: 5.2161
# Epoch [32/150], Step [67/67], d_loss: 0.9254, g_loss: 2.9285
# Epoch [33/150], Step [67/67], d_loss: 0.5712, g_loss: 5.8132
# Epoch [34/150], Step [67/67], d_loss: 0.5424, g_loss: 3.8104
# Epoch [35/150], Step [67/67], d_loss: 0.7784, g_loss: 2.6392
# Epoch [36/150], Step [67/67], d_loss: 0.6171, g_loss: 4.2896
# Epoch [37/150], Step [67/67], d_loss: 0.3990, g_loss: 5.0290
# Epoch [38/150], Step [67/67], d_loss: 0.3408, g_loss: 5.3970
# Epoch [39/150], Step [67/67], d_loss: 0.3553, g_loss: 5.5129
# Epoch [40/150], Step [67/67], d_loss: 0.3610, g_loss: 7.4929
# Epoch [41/150], Step [67/67], d_loss: 0.5762, g_loss: 7.3880
# Epoch [42/150], Step [67/67], d_loss: 0.3859, g_loss: 4.1883
# Epoch [43/150], Step [67/67], d_loss: 0.3816, g_loss: 3.3091
# Epoch [44/150], Step [67/67], d_loss: 0.3279, g_loss: 5.2712
# Epoch [45/150], Step [67/67], d_loss: 0.3105, g_loss: 4.1059
# Epoch [46/150], Step [67/67], d_loss: 0.1302, g_loss: 5.7195
# Epoch [47/150], Step [67/67], d_loss: 0.1277, g_loss: 5.1193
# Epoch [48/150], Step [67/67], d_loss: 0.0943, g_loss: 5.1297
# Epoch [49/150], Step [67/67], d_loss: 0.4676, g_loss: 10.3736
# Epoch [50/150], Step [67/67], d_loss: 0.3414, g_loss: 4.9966
# Epoch [51/150], Step [67/67], d_loss: 0.5565, g_loss: 8.2009
# Epoch [52/150], Step [67/67], d_loss: 0.2327, g_loss: 6.8266
# Epoch [53/150], Step [67/67], d_loss: 0.2797, g_loss: 2.7824
# Epoch [54/150], Step [67/67], d_loss: 0.3710, g_loss: 8.0846
# Epoch [55/150], Step [67/67], d_loss: 0.2061, g_loss: 7.7509
# Epoch [56/150], Step [67/67], d_loss: 0.8123, g_loss: 9.3550
# Epoch [57/150], Step [67/67], d_loss: 0.2259, g_loss: 4.0116
# Epoch [58/150], Step [67/67], d_loss: 0.2306, g_loss: 4.1852
# Epoch [59/150], Step [67/67], d_loss: 0.1533, g_loss: 5.3555
# Epoch [60/150], Step [67/67], d_loss: 0.1807, g_loss: 8.0158
# Epoch [61/150], Step [67/67], d_loss: 0.1213, g_loss: 3.9325
# Epoch [62/150], Step [67/67], d_loss: 0.0835, g_loss: 6.3088
# Epoch [63/150], Step [67/67], d_loss: 0.2409, g_loss: 4.7712
# Epoch [64/150], Step [67/67], d_loss: 1.4425, g_loss: 10.8223
# Epoch [65/150], Step [67/67], d_loss: 0.4848, g_loss: 9.3657
# Epoch [66/150], Step [67/67], d_loss: 0.2424, g_loss: 6.5967
# Epoch [67/150], Step [67/67], d_loss: 0.1460, g_loss: 4.4703
# Epoch [68/150], Step [67/67], d_loss: 0.0503, g_loss: 4.9177
# Epoch [69/150], Step [67/67], d_loss: 0.0373, g_loss: 6.9095
# Epoch [70/150], Step [67/67], d_loss: 0.0320, g_loss: 6.4191
# Epoch [71/150], Step [67/67], d_loss: 0.1746, g_loss: 8.5280
# Epoch [72/150], Step [67/67], d_loss: 0.0506, g_loss: 7.1473
# Epoch [73/150], Step [67/67], d_loss: 0.0499, g_loss: 6.5196
# Epoch [74/150], Step [67/67], d_loss: 0.2955, g_loss: 6.0002
# Epoch [75/150], Step [67/67], d_loss: 0.2524, g_loss: 10.1053
# Epoch [76/150], Step [67/67], d_loss: 0.0247, g_loss: 7.7168
# Epoch [77/150], Step [67/67], d_loss: 1.8789, g_loss: 11.9206
# Epoch [78/150], Step [67/67], d_loss: 0.6855, g_loss: 9.8527
# Epoch [79/150], Step [67/67], d_loss: 0.4107, g_loss: 6.5791
# Epoch [80/150], Step [67/67], d_loss: 0.0940, g_loss: 5.6013
# Epoch [81/150], Step [67/67], d_loss: 0.2128, g_loss: 6.8859
# Epoch [82/150], Step [67/67], d_loss: 0.0509, g_loss: 6.7479
# Epoch [83/150], Step [67/67], d_loss: 0.0651, g_loss: 6.4350
# Epoch [84/150], Step [67/67], d_loss: 0.0857, g_loss: 4.9883
# Epoch [85/150], Step [67/67], d_loss: 0.9972, g_loss: 2.9534
# Epoch [86/150], Step [67/67], d_loss: 0.1744, g_loss: 6.0472
# Epoch [87/150], Step [67/67], d_loss: 0.0572, g_loss: 7.9558
# Epoch [88/150], Step [67/67], d_loss: 0.0802, g_loss: 7.2991
# Epoch [89/150], Step [67/67], d_loss: 0.2803, g_loss: 5.6062
# Epoch [90/150], Step [67/67], d_loss: 0.1109, g_loss: 8.0737
# Epoch [91/150], Step [67/67], d_loss: 0.2391, g_loss: 3.2051
# Epoch [92/150], Step [67/67], d_loss: 0.0341, g_loss: 6.4768
# Epoch [93/150], Step [67/67], d_loss: 0.0389, g_loss: 5.9381
# Epoch [94/150], Step [67/67], d_loss: 0.0175, g_loss: 6.8802
# Epoch [95/150], Step [67/67], d_loss: 0.0314, g_loss: 7.1631
# Epoch [96/150], Step [67/67], d_loss: 0.3263, g_loss: 6.6365
# Epoch [97/150], Step [67/67], d_loss: 1.0007, g_loss: 15.6080
# Epoch [98/150], Step [67/67], d_loss: 0.2535, g_loss: 8.6862
# Epoch [99/150], Step [67/67], d_loss: 0.3166, g_loss: 5.6108
# Epoch [100/150], Step [67/67], d_loss: 0.0638, g_loss: 7.0101
# Epoch [101/150], Step [67/67], d_loss: 0.0468, g_loss: 5.6404
# Epoch [102/150], Step [67/67], d_loss: 0.0939, g_loss: 6.1469
# Epoch [103/150], Step [67/67], d_loss: 0.0658, g_loss: 8.0012
# Epoch [104/150], Step [67/67], d_loss: 0.0139, g_loss: 6.5523
# Epoch [105/150], Step [67/67], d_loss: 0.2356, g_loss: 6.0718
# Epoch [106/150], Step [67/67], d_loss: 0.0842, g_loss: 7.0016
# Epoch [107/150], Step [67/67], d_loss: 0.3875, g_loss: 1.6742
# Epoch [108/150], Step [67/67], d_loss: 0.5745, g_loss: 4.1020
# Epoch [109/150], Step [67/67], d_loss: 0.2374, g_loss: 2.9760
# Epoch [110/150], Step [67/67], d_loss: 0.1289, g_loss: 5.8085
# Epoch [111/150], Step [67/67], d_loss: 0.1067, g_loss: 5.2700
# Epoch [112/150], Step [67/67], d_loss: 0.1879, g_loss: 5.4707
# Epoch [113/150], Step [67/67], d_loss: 0.0273, g_loss: 6.3653
# Epoch [114/150], Step [67/67], d_loss: 0.0258, g_loss: 6.9446
# Epoch [115/150], Step [67/67], d_loss: 0.0351, g_loss: 6.7283
# Epoch [116/150], Step [67/67], d_loss: 0.0259, g_loss: 6.3824
# Epoch [117/150], Step [67/67], d_loss: 0.0198, g_loss: 6.7543
# Epoch [118/150], Step [67/67], d_loss: 0.0163, g_loss: 7.5060
# Epoch [119/150], Step [67/67], d_loss: 0.0287, g_loss: 7.0175
# Epoch [120/150], Step [67/67], d_loss: 0.0845, g_loss: 8.8589
# Epoch [121/150], Step [67/67], d_loss: 0.1154, g_loss: 12.0319
# Epoch [122/150], Step [67/67], d_loss: 0.5660, g_loss: 14.6016
# Epoch [123/150], Step [67/67], d_loss: 0.0413, g_loss: 7.3539
# Epoch [124/150], Step [67/67], d_loss: 0.2340, g_loss: 12.8531
# Epoch [125/150], Step [67/67], d_loss: 0.0835, g_loss: 6.9825
# Epoch [126/150], Step [67/67], d_loss: 0.0467, g_loss: 6.6998
# Epoch [127/150], Step [67/67], d_loss: 0.0488, g_loss: 6.8798
# Epoch [128/150], Step [67/67], d_loss: 0.0211, g_loss: 9.0015
# Epoch [129/150], Step [67/67], d_loss: 0.0135, g_loss: 7.6583
# Epoch [130/150], Step [67/67], d_loss: 0.0590, g_loss: 7.4438
# Epoch [131/150], Step [67/67], d_loss: 0.0163, g_loss: 7.7042
# Epoch [132/150], Step [67/67], d_loss: 0.0205, g_loss: 7.6955
# Epoch [133/150], Step [67/67], d_loss: 1.9403, g_loss: 17.1290
# Epoch [134/150], Step [67/67], d_loss: 0.0487, g_loss: 8.0307
# Epoch [135/150], Step [67/67], d_loss: 0.0772, g_loss: 5.2233
# Epoch [136/150], Step [67/67], d_loss: 0.1943, g_loss: 6.8887
# Epoch [137/150], Step [67/67], d_loss: 0.1684, g_loss: 3.0577
# Epoch [138/150], Step [67/67], d_loss: 0.0463, g_loss: 5.3599
# Epoch [139/150], Step [67/67], d_loss: 0.0101, g_loss: 6.5294
# Epoch [140/150], Step [67/67], d_loss: 0.1291, g_loss: 4.4742
# Epoch [141/150], Step [67/67], d_loss: 0.0885, g_loss: 11.4836
# Epoch [142/150], Step [67/67], d_loss: 0.0148, g_loss: 6.0465
# Epoch [143/150], Step [67/67], d_loss: 0.1025, g_loss: 7.0476
# Epoch [144/150], Step [67/67], d_loss: 0.0173, g_loss: 8.0787
# Epoch [145/150], Step [67/67], d_loss: 0.0261, g_loss: 6.7966
# Epoch [146/150], Step [67/67], d_loss: 0.5102, g_loss: 13.0718
# Epoch [147/150], Step [67/67], d_loss: 0.0631, g_loss: 7.0429
# Epoch [148/150], Step [67/67], d_loss: 0.0631, g_loss: 7.1150
# Epoch [149/150], Step [67/67], d_loss: 0.0623, g_loss: 5.6339
# Epoch [150/150], Step [67/67], d_loss: 0.0238, g_loss: 6.8704

# %%
from torchvision.utils import make_grid

sample_z = torch.randn(16, latent_size, 1, 1).to(device)
sample_generated_images = gen(sample_z)
print(sample_generated_images.shape)
generated = sample_generated_images.detach().cpu()
plt.figure(figsize = (10,10))
sample_grid = make_grid(generated, nrow=4, normalize=True)
plt.imshow(np.transpose(sample_grid, (1, 2, 0)))
plt.axis('off')
plt.title('Grid of Generated Images')
plt.show()
# Out:
# torch.Size([16, 3, 64, 64])

# %%
plt.figure(figsize=(10,3))
ax1 = plt.subplot(1, 2, 1)
ax1.plot(finalg)
plt.title('Generator Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
ax2=plt.subplot(1, 2, 2)
ax2.plot(finald)
plt.title('Discriminator Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.plot(finalg,label='g')
plt.plot(finald,label='d')
plt.legend()
plt.show()

# %%
test_batch_size=13

test_dataset = datasets.ImageFolder('./city/test',transform=transform)
test_loader = DataLoader(test_dataset, test_batch_size, shuffle=True, num_workers=2)

def sample_images():
    gen.eval()
    with torch.no_grad():
        z = torch.randn(test_batch_size, latent_size, 1, 1).to(device)
        generated_images = gen(z)
    return generated_images
def interpolate(batch):
    arr = []
    for img in batch:
        pil_img = T.ToPILImage()(img)
        resized_img = pil_img.resize((299,299), Image.BILINEAR)
        arr.append(T.ToTensor()(resized_img))
    return torch.stack(arr)
def get_fake():
    return sample_images()
def evaluation_step(engine, batch):
    with torch.no_grad():
        fake = get_fake()
        fake = interpolate(fake.cpu())
        real = interpolate(batch[0])
        return fake, real
fid_metric = FID(device=device)
is_metric = InceptionScore(device=device, output_transform=lambda x: x[0])
evaluator = Engine(evaluation_step)
fid_metric.attach(evaluator, "fid")
is_metric.attach(evaluator, "is")
evaluator.run(test_loader, max_epochs=1)
metrics = evaluator.state.metrics
fid_score = metrics['fid']
is_score = metrics['is']

# %%
print('fid_score: '+str(fid_score))
print('is_score: '+ str(is_score))
# Out:
# fid_score: 0.05271258931969805
# is_score: 2.1482686740308843
